# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df_data = pd.read_csv(r"C:\Users\heumo\Machine learning\Hackaton\events.csv")
df_data
# Out:
#                      event_time event_type  product_id          category_id  \
# 0       2020-09-24 11:57:06 UTC       view     1996170  2144415922528452715
# 1       2020-09-24 11:57:26 UTC       view      139905  2144415926932472027
# 2       2020-09-24 11:57:27 UTC       view      215454  2144415927158964449
# 3       2020-09-24 11:57:33 UTC       view      635807  2144415923107266682
# 4       2020-09-24 11:57:36 UTC       view     3658723  2144415921169498184
# ...                         ...        ...         ...                  ...
# 885124  2021-02-28 23:55:01 UTC       view      953226  2144415927553229037
# 885125  2021-02-28 23:58:05 UTC       view     1715907  2144415927049912542
# 885126  2021-02-28 23:58:09 UTC       view     4170534  2144415939364389423
# 885127  2021-02-28 23:58:14 UTC       view      888273  2144415921932861531
# 885128  2021-02-28 23:59:09 UTC       view      743182  2144415935631458761
#
#                         category_code        brand   price  \
# 0               electronics.telephone          NaN   31.90
# 1         computers.components.cooler       zalman   17.16
# 2                                 NaN          NaN    9.81
# 3       computers.peripherals.printer       pantum  113.81
# 4                                 NaN  cameronsino   15.87
# ...                               ...          ...     ...
# 885124                            NaN          NaN  219.94
# 885125           electronics.video.tv     starwind   80.03
# 885126             electronics.clocks      amazfit   64.92
# 885127          electronics.telephone          NaN   10.16
# 885128   construction.tools.soldering         kada   65.08
#
#                     user_id user_session
# 0       1515915625519388267   LJuJVLEjPT
# 1       1515915625519380411   tdicluNnRY
# 2       1515915625513238515   4TMArHtXQy
# 3       1515915625519014356   aGFYrNgC08
# 4       1515915625510743344   aa4mmk0kwQ
# ...                     ...          ...
# 885124  1515915625611023730   FRLqIttxKU
# 885125  1515915625611024014   g6WqPf50Ma
# 885126  1515915625611024020   xNIJBqZdkd
# 885127  1515915625611024030   9pCbKMIcSx
# 885128  1515915625556087775   BejOXRngEW
#
# [885129 rows x 9 columns]

# %%
df_data.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
df_data.describe().T
# Out:
#                 count          mean           std           min           25%  \
# product_id   885129.0  1.906621e+06  1.458708e+06  1.020000e+02  6.988030e+05
# category_id  885129.0  2.144423e+18  6.165105e+14  2.144416e+18  2.144416e+18
# price        885129.0  1.463287e+02  2.968077e+02  2.200000e-01  2.646000e+01
# user_id      885129.0  1.515916e+18  3.554165e+07  1.515916e+18  1.515916e+18
#
#                       50%           75%           max
# product_id   1.452883e+06  3.721194e+06  4.183880e+06
# category_id  2.144416e+18  2.144416e+18  2.227847e+18
# price        6.571000e+01  1.904900e+02  6.477106e+04
# user_id      1.515916e+18  1.515916e+18  1.515916e+18

# %%
#Vérifier les valeurs nulls du data set
df_data.isnull().sum()
# Out:
# event_time            0
# event_type            0
# product_id            0
# category_id           0
# category_code    236219
# brand            212364
# price                 0
# user_id               0
# user_session        165
# dtype: int64

# %%
df_data.dtypes
# Out:
# event_time        object
# event_type        object
# product_id         int64
# category_id        int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object

# %%
# Valeur unique de chaque colonne
#df_data.event_type.unique()
#df_data.user_session.unique()
df_data.category_code.unique()
# Out:
# array(['electronics.telephone', 'computers.components.cooler', nan,
#        'computers.peripherals.printer', 'construction.tools.saw',
#        'computers.desktop', 'computers.network.router',
#        'electronics.video.tv', 'auto.accessories.player',
#        'computers.components.motherboard', 'electronics.camera.video',
#        'computers.peripherals.keyboard', 'computers.components.hdd',
#        'electronics.audio.acoustic', 'computers.components.power_supply',
#        'appliances.steam_cleaner', 'computers.components.cpu',
#        'construction.tools.welding', 'appliances.kitchen.juicer',
#        'computers.peripherals.scanner', 'computers.peripherals.camera',
#        'electronics.tablet', 'computers.peripherals.nas',
#        'stationery.cartrige', 'computers.components.network_adapter',
#        'computers.peripherals.joystick', 'appliances.sewing_machine',
#        'computers.peripherals.wifi', 'electronics.audio.dictaphone',
#        'appliances.environment.vacuum', 'electronics.clocks',
#        'electronics.audio.headphone', 'computers.components.videocards',
#        'auto.accessories.alarm', 'appliances.kitchen.kettle',
#        'furniture.living_room.shelving', 'computers.peripherals.mouse',
#        'construction.tools.screw', 'construction.tools.pump',
#        'auto.accessories.window', 'computers.components.tv_tuner',
#        'kids.skates', 'computers.peripherals.vr',
#        'construction.tools.soldering', 'computers.notebook',
#        'appliances.kitchen.microwave', 'auto.accessories.radar',
#        'accessories.bag', 'construction.tools.drill',
#        'auto.accessories.parktronic', 'stationery.paper',
#        'computers.peripherals.monitor', 'electronics.video.projector',
#        'appliances.kitchen.coffee_machine', 'computers.ebooks',
#        'appliances.kitchen.blender', 'stationery.battery',
#        'electronics.audio.microphone', 'stationery.stapler',
#        'appliances.kitchen.fryer', 'construction.tools.light',
#        'country_yard.cultivator', 'appliances.iron',
#        'appliances.environment.air_heater', 'auto.accessories.gps',
#        'computers.components.cdrw', 'auto.accessories.videoregister',
#        'appliances.kitchen.mixer', 'electronics.video.tv_remote',
#        'apparel.glove', 'appliances.kitchen.washer',
#        'appliances.kitchen.meat_grinder', 'appliances.kitchen.grill',
#        'auto.accessories.compressor',
#        'electronics.audio.music_tools.piano', 'construction.tools.wrench',
#        'appliances.kitchen.steam_cooker',
#        'appliances.kitchen.coffee_grinder',
#        'appliances.personal.massager', 'country_yard.weather_station',
#        'appliances.personal.hair_cutter',
#        'computers.components.sound_card', 'construction.tools.heater',
#        'kids.toys', 'appliances.environment.fan',
#        'electronics.calculator', 'construction.tools.generator',
#        'appliances.personal.scales', 'appliances.kitchen.toster',
#        'medicine.tools.tonometer', 'construction.tools.painting',
#        'furniture.bathroom.bath', 'sport.bicycle',
#        'electronics.camera.photo', 'computers.gaming',
#        'auto.accessories.immobilizer', 'country_yard.lawn_mower',
#        'electronics.fax', 'country_yard.watering', 'jewelry.souvenir',
#        'auto.accessories.light', 'jewelry.ring',
#        'furniture.living_room.chair', 'appliances.kitchen.refrigerators',
#        'accessories.briefcase', 'auto.accessories.winch',
#        'furniture.kitchen.chair', 'furniture.bedroom.blanket'],
#       dtype=object)

# %%
noms_separes = df_data['category_code'].str.split(',', expand=True)

# %%
# Fonction pour extraire les deux premiers et le dernier mot
def extraire_mots(chaine):
    mots = chaine.split()
    if len(mots) >= 3:
        return mots[0], mots[1], mots[-1]
    elif len(mots) == 2:
        return mots[0], mots[1], mots[1]
    elif len(mots) == 1:
        return mots[0], '', mots[0]
    else:
        return '', '', ''
    # Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 13
#      11         return '', '', ''
#      12     # Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
# ---> 13 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[39], line 13, in <lambda>(x)
#      11         return '', '', ''
#      12     # Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
# ---> 13 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#
# Cell In[39], line 3, in extraire_mots(chaine)
#       2 def extraire_mots(chaine):
# ----> 3     mots = chaine.split()
#       4     if len(mots) >= 3:
#       5         return mots[0], mots[1], mots[-1]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))

# Afficher le DataFrame résultant
print(df_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
# ----> 2 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#       4 # Afficher le DataFrame résultant
#       5 print(df_data)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[38], line 2, in <lambda>(x)
#       1 # Appliquer la fonction à la colonne 'textes' et créer de nouvelles colonnes
# ----> 2 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#       4 # Afficher le DataFrame résultant
#       5 print(df_data)
#
# Cell In[37], line 3, in extraire_mots(chaine)
#       2 def extraire_mots(chaine):
# ----> 3     mots = chaine.split(',')
#       4     if len(mots) >= 3:
#       5         return mots[0], mots[1], mots[-1]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Fonction pour extraire les deux premiers et le dernier mot
def extraire_mots(chaine):
    mots = chaine.split(',')
    if len(mots) >= 3:
        return mots[0], mots[1], mots[-1]
    elif len(mots) == 2:
        return mots[0], mots[1], mots[1]
    elif len(mots) == 1:
        return mots[0], '', mots[0]
    else:
        return '', '', ''

# Appliquer la fonction à la colonne 'category_code' et créer de nouvelles colonnes
df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 14
#      11         return '', '', ''
#      13 # Appliquer la fonction à la colonne 'category_code' et créer de nouvelles colonnes
# ---> 14 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\heumo\Machine learning\Hackaton\venv_projet_hackaton\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[41], line 14, in <lambda>(x)
#      11         return '', '', ''
#      13 # Appliquer la fonction à la colonne 'category_code' et créer de nouvelles colonnes
# ---> 14 df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))
#
# Cell In[41], line 3, in extraire_mots(chaine)
#       2 def extraire_mots(chaine):
# ----> 3     mots = chaine.split(',')
#       4     if len(mots) >= 3:
#       5         return mots[0], mots[1], mots[-1]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Fonction pour extraire les deux premiers et le dernier mot
def extraire_mots(chaine):
    if isinstance(chaine, str):  # Vérifie si la valeur est une chaîne de caractères
        mots = chaine.split('.')
        if len(mots) >= 3:
            return mots[0], mots[1], mots[-1]
        elif len(mots) == 2:
            return mots[0], mots[1], mots[1]
        elif len(mots) == 1:
            return mots[0], '', mots[0]
    return '', '', ''

# Convertir la colonne 'category_code' en chaînes de caractères
df_data['category_code'] = df_data['category_code'].astype(str)

# Appliquer la fonction à la colonne 'category_code' et créer de nouvelles colonnes
df_data[['premier_mot', 'deuxieme_mot', 'dernier_mot']] = df_data['category_code'].apply(lambda x: pd.Series(extraire_mots(x)))

# %%
df_data
# Out:
#                      event_time event_type  product_id          category_id  \
# 0       2020-09-24 11:57:06 UTC       view     1996170  2144415922528452715
# 1       2020-09-24 11:57:26 UTC       view      139905  2144415926932472027
# 2       2020-09-24 11:57:27 UTC       view      215454  2144415927158964449
# 3       2020-09-24 11:57:33 UTC       view      635807  2144415923107266682
# 4       2020-09-24 11:57:36 UTC       view     3658723  2144415921169498184
# ...                         ...        ...         ...                  ...
# 885124  2021-02-28 23:55:01 UTC       view      953226  2144415927553229037
# 885125  2021-02-28 23:58:05 UTC       view     1715907  2144415927049912542
# 885126  2021-02-28 23:58:09 UTC       view     4170534  2144415939364389423
# 885127  2021-02-28 23:58:14 UTC       view      888273  2144415921932861531
# 885128  2021-02-28 23:59:09 UTC       view      743182  2144415935631458761
#
#                         category_code        brand   price  \
# 0               electronics.telephone          NaN   31.90
# 1         computers.components.cooler       zalman   17.16
# 2                                 nan          NaN    9.81
# 3       computers.peripherals.printer       pantum  113.81
# 4                                 nan  cameronsino   15.87
# ...                               ...          ...     ...
# 885124                            nan          NaN  219.94
# 885125           electronics.video.tv     starwind   80.03
# 885126             electronics.clocks      amazfit   64.92
# 885127          electronics.telephone          NaN   10.16
# 885128   construction.tools.soldering         kada   65.08
#
#                     user_id user_session   premier_mot deuxieme_mot  \
# 0       1515915625519388267   LJuJVLEjPT   electronics    telephone
# 1       1515915625519380411   tdicluNnRY     computers   components
# 2       1515915625513238515   4TMArHtXQy           nan
# 3       1515915625519014356   aGFYrNgC08     computers  peripherals
# 4       1515915625510743344   aa4mmk0kwQ           nan
# ...                     ...          ...           ...          ...
# 885124  1515915625611023730   FRLqIttxKU           nan
# 885125  1515915625611024014   g6WqPf50Ma   electronics        video
# 885126  1515915625611024020   xNIJBqZdkd   electronics       clocks
# 885127  1515915625611024030   9pCbKMIcSx   electronics    telephone
# 885128  1515915625556087775   BejOXRngEW  construction        tools
#
#        dernier_mot
# 0        telephone
# 1           cooler
# 2              nan
# 3          printer
# 4              nan
# ...            ...
# 885124         nan
# 885125          tv
# 885126      clocks
# 885127   telephone
# 885128   soldering
#
# [885129 rows x 12 columns]
